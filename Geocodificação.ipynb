# %%
import pandas as pd # Para carregar a planilha com os endereços
import geopandas as gpds
import re
import shapely.geometry
import geopy

# %%
df = pd.read_csv('data_set_grande_recife.csv')

# %%
df.head(2)
# Out:
#                   Nome da linha  \
# 0  1935 Paratibe / TI Pelópidas
# 1  1935 Paratibe / TI Pelópidas
#
#                                          Nome da rua  \
# 0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1  Av. Lindolfo Collor, 127 | Escola Custódio Pessoa
#
#                                    Endereço completo      Estado    País  \
# 0  Av. Lindolfo Collor, 03 | Miniterminal De Para...  Pernambuco  Brasil
# 1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...  Pernambuco  Brasil
#
#    Ordem
# 0      0
# 1      1

# %%
df.shape
# Out:
# (36940, 6)

# %%
endereços_distintos = df["Endereço completo"].unique()
len(endereços_distintos)
# Out:
# 9147

# %%
endereços_completissimos = []
points = []

# %%
df_ends_points = pd.DataFrame({"Endereço semicompleto": [], "Endereço geocode": [], "Points": []})

# %%
df_ends_points['Points'][0]
# Out:
# '0    POINT (-34.89865 -7.93516)\nName: geometry, dtype: geometry'

# %%
geocodif.geometry.x
# Out:
# 0   -34.898647
# dtype: float64

# %%
df_ends_points['Points'][0].x
# Out:
# 0   -34.898647
# dtype: float64

# %%
geocodif["geometry"].x
# Out:
# 0   -34.898647
# dtype: float64

# %%
for endereço in endereços_distintos:
    geocodif = gpds.tools.geocode(endereço, provider = "google", user_agent="Intro Geocode", api_key="AIzaSyAt2800EHvRPwF6tSIz3gim51knlQMPH8g")
    df_ends_points = df_ends_points.append({"Endereço semicompleto": endereço, "Endereço geocode": str(geocodif["address"]), "Points": geocodif["geometry"]}, ignore_index=True)

# %%
df_ends_points
# Out:
#                                   Endereço semicompleto  \
# 0     Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1     Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2     Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3     Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4     Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...                                                 ...
# 9142  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9143  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9144  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9145   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9146  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode  \
# 0     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 1     0    Av. Lindolfo Collor, SN - Paratibe, Pauli...
# 2     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 3     0    Praça da Liberdade - Av. Lindolfo Collor ...
# ...

# %%
df_ends_points.to_csv("endereços_e_points.csv", encoding="utf-8")

# %%
for index, row in df_ends_points.iterrows():
    point_temp = str(row['Points']).replace("0    POINT (","")
    point_temp = point_temp.replace(")\nName: geometry, dtype: geometry","")
    df_ends_points['Points'].iloc[index] = point_temp.replace(" ", ", ")

# %%
points_x_y = df_ends_points["Points"].str.split(", ", expand=True)
points_x_y.rename(columns={0: 'x', 1: 'y'}, inplace = True)
points_x_y
# Out:
#               x         y     2     3     4     5     6     7     8
# 0     -34.89865  -7.93516  None  None  None  None  None  None  None
# 1     -34.89885  -7.93326  None  None  None  None  None  None  None
# 2     -34.89865  -7.93516  None  None  None  None  None  None  None
# 3     -34.89871  -7.93639  None  None  None  None  None  None  None
# 4     -34.89884  -7.93580  None  None  None  None  None  None  None
# ...         ...       ...   ...   ...   ...   ...   ...   ...   ...
# 9142  -34.86736  -7.96962  None  None  None  None  None  None  None
# 9143  -34.86740  -7.96981  None  None  None  None  None  None  None
# 9144  -34.86606  -7.97150  None  None  None  None  None  None  None
# 9145  -34.86641  -7.97144  None  None  None  None  None  None  None
# 9146  -34.85657  -7.98263  None  None  None  None  None  None  None
#
# [9147 rows x 9 columns]

# %%
points_x_y.drop(columns=[2,3,4,5,6,7,8], inplace=True)
points_x_y.head(2)
# Out:
#            x         y
# 0  -34.89865  -7.93516
# 1  -34.89885  -7.93326

# %%
df_ends_points.head(3)
# Out:
#                                Endereço semicompleto  \
# 0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
#
#                                     Endereço geocode  \
# 0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 1  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...
# 2  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
#
#                                               Points
# 0  0    POINT (-34.89865 -7.93516)\nName: geometr...
# 1  0    POINT (-34.89885 -7.93326)\nName: geometr...
# 2  0    POINT (-34.89865 -7.93516)\nName: geometr...

# %%
df_ends_points = pd.concat([df_ends_points, points_x_y], axis=1)
df_ends_points.head(2)
# Out:
#                                Endereço semicompleto  \
# 0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
#
#                                     Endereço geocode  \
# 0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 1  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...
#
#                                               Points          x         y
# 0  0    POINT (-34.89865 -7.93516)\nName: geometr...  -34.89865  -7.93516
# 1  0    POINT (-34.89885 -7.93326)\nName: geometr...  -34.89885  -7.93326

# %%
df_ends_points.to_csv("endereços_e_points.csv", encoding='utf-8')

# %%
df_ends_points = pd.read_csv("endereços_e_points2.csv", encoding='utf-8')

# %%
df_ends_points.drop(columns='Unnamed: 0')
# Out:
#                                   Endereço semicompleto  \
# 0     Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1     Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2     Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3     Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4     Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...                                                 ...
# 9142  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9143  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9144  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9145   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9146  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode               Points  \
# 0     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 1     0    Av. Lindolfo Collor, SN - Paratibe, Pauli...  -34.89885, -7.93326
# ...

# %%
type(df_ends_points['y'][0])
# Out:
# numpy.float64

# %%
df_ends_points['Coord'] = df_ends_points['y'].map(str) + ", " + df_ends_points['x'].map(str)
df_ends_points.head()
# Out:
#    Unnamed: 0                              Endereço semicompleto  \
# 0           0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1           1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2           2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3           3  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4           4  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
#
#                                     Endereço geocode               Points  \
# 0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 1  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...  -34.89885, -7.93326
# 2  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 3  0    Praça da Liberdade - Av. Lindolfo Collor ...  -34.89871, -7.93639
# 4  0    Av. Lindolfo Collor, 86 - Paratibe, Pauli...  -34.89884, -7.93580
#
#           x        y                Coord
# 0 -34.89865 -7.93516  -7.93516, -34.89865
# 1 -34.89885 -7.93326  -7.93326, -34.89885
# ...

# %%
coorden = pd.DataFrame()

# %%
df_ends_points['Endereço completíssimo'] = ""

# %%
df_ends_points
# Out:
#       Unnamed: 0                              Endereço semicompleto  \
# 0              0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1              1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2              2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3              3  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4              4  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...          ...                                                ...
# 9142        9142  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9143        9143  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9144        9144  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9145        9145   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9146        9146  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode               Points  \
# ...

# %%
df_ends_points2 = df_ends_points[df_ends_points['Endereço completíssimo']==""]
df_ends_points2

# %%
type(df_ends_points['Points'][0])
# Out:
# str

# %%
df_ends_points3 = df_ends_points[df_ends_points['x'].isna() |df_ends_points['y'].isna() ]

# %%
df_ends_points_sem_na = df_ends_points[df_ends_points['x'].notna() & df_ends_points['y'].notna() ]

# %%
df_ends_points_sem_na
# Out:
#       Unnamed: 0                              Endereço semicompleto  \
# 0              0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1              1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2              2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3              3  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4              4  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...          ...                                                ...
# 9142        9142  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9143        9143  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9144        9144  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9145        9145   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9146        9146  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode               Points  \
# ...

# %%
df_ends_points_sem_na['Endereço completíssimo'] = endereços_completissimos_lista
df_ends_points_sem_na
# Out:
# c:\users\vanessa.da.conceicao\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Unnamed: 0                              Endereço semicompleto  \
# 0              0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1              1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2              2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3              3  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4              4  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...          ...                                                ...
# ...

# %%
df_ends_points_sem_na.to_csv("df_ends_points_sem_na.csv", encoding='utf-8')

# %%
df_ends_points_sem_na['Endereço completíssimo'][0].raw['address']['road']
# Out:
# 'Avenida Lindolfo Collor'

# %%
df_ends_points_sem_na.shape
# Out:
# (9109, 8)

# %%
df_end_dict.shape
# Out:
# (9109, 5)

# %%
len(endereços_completissimos_lista)
# Out:
# 9109

# %%
dicionario_endereços = {"Rua": [], "Bairro": [], "Cidade": [], "Mesoregião": [], "Estado_": []}

# %%
len(dicionario_endereços['Bairro'])
# Out:
# 9109

# %%
df_end_dict.to_csv("df_end_dict.csv", encoding='utf-8')

# %%
df_teste = pd.concat([df_ends_points_sem_na, df_end_dict], axis=1)
df_teste
# Out:
#       Unnamed: 0                              Endereço semicompleto  \
# 0            0.0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1            1.0  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2            2.0  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3            3.0  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4            4.0  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...          ...                                                ...
# 9142      9142.0  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9143      9143.0  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9144      9144.0  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9145      9145.0   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9146      9146.0  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode               Points  \
# ...

# %%
df_end_dict = pd.DataFrame(dicionario_endereços)
df_end_dict
# Out:
#                           Rua           Bairro    Cidade  \
# 0     Avenida Lindolfo Collor         Paratibe  Paulista
# 1     Avenida Lindolfo Collor         Paratibe  Paulista
# 2     Avenida Lindolfo Collor         Paratibe  Paulista
# 3     Avenida Lindolfo Collor         Paratibe  Paulista
# 4     Avenida Lindolfo Collor         Paratibe  Paulista
# ...                       ...              ...       ...
# 9104         Avenida Tabajara  Cidade Tabajara    Olinda
# 9105         Avenida Tabajara  Cidade Tabajara    Olinda
# 9106         Avenida Tabajara  Cidade Tabajara    Olinda
# 9107                Rua Jutaí  Cidade Tabajara    Olinda
# 9108   Avenida Pan Nordestina          Fragoso    Olinda
#
#                           Mesoregião     Estado_
# 0     Região Metropolitana do Recife  Pernambuco
# 1     Região Metropolitana do Recife  Pernambuco
# 2     Região Metropolitana do Recife  Pernambuco
# 3     Região Metropolitana do Recife  Pernambuco
# ...

# %%
len(dicionario_endereços['Rua'])
# Out:
# 9109

# %%
df_ends_points_sem_na = pd.read_csv("df_ends_points_sem_na.csv", encoding = 'utf-8')
df_ends_points_sem_na
# Out:
#                                   Endereço semicompleto  \
# 0     Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1     Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2     Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3     Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4     Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
# ...                                                 ...
# 9104  Av. Tabajara, 55 | Panificadora Real Pan, Pern...
# 9105  52 A Avenida Tabajara, Olinda, Pernambuco - Br...
# 9106  Av. Tabajara, 08 | Farmácia Para O Trabalhador...
# 9107   SN Avenida Tabajara, Olinda, Pernambuco - Brasil
# 9108  Pe-15, 68 | Pan Julia - Pista Local, Pernambuc...
#
#                                        Endereço geocode               Points  \
# 0     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 1     0    Av. Lindolfo Collor, SN - Paratibe, Pauli...  -34.89885, -7.93326
# ...

# %%
endereços_completissimos_lista = df_ends_points_sem_na['Endereço completíssimo'].values
endereços_completissimos_lista
# Out:
# array(['140408, Avenida Lindolfo Collor, Paratibe, Paulista, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53417-040, Brasil',
#        'Avenida Lindolfo Collor, Paratibe, Paulista, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53417-040, Brasil',
#        '140408, Avenida Lindolfo Collor, Paratibe, Paulista, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53417-040, Brasil',
#        ...,
#        '140127, Avenida Tabajara, Cidade Tabajara, Tabajara, Olinda, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53350-005, Brasil',
#        '140130, Rua Jutaí, Cidade Tabajara, Tabajara, Olinda, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53350-005, Brasil',
# ...

# %%
for endereço in endereços_completissimos_lista:
    print(endereço.raw)
    dicionario_endereços['Rua'].append(endereço.raw['address']['road'] if 'road' in endereço.raw['address'].keys() else "")
    dicionario_endereços['Bairro'].append(endereço.raw['address']['suburb'] if 'suburb' in endereço.raw['address'].keys() else  "")
    dicionario_endereços['Cidade'].append(endereço.raw['address']['city'] if 'city' in endereço.raw['address'].keys() else  "")
    dicionario_endereços['Mesoregião'].append(endereço.raw['address']['county'] if 'county' in endereço.raw['address'].keys() else  "")
    dicionario_endereços['Estado_'].append(endereço.raw['address']['state'] if 'state' in endereço.raw['address'].keys() else  "")
# Out:
# {'place_id': 25821276, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2633211654, 'lat': '-7.9349966', 'lon': '-34.8987094', 'display_name': '140408, Avenida Lindolfo Collor, Paratibe, Paulista, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53417-040, Brasil', 'address': {'highway': '140408', 'road': 'Avenida Lindolfo Collor', 'suburb': 'Paratibe', 'city_district': 'Paulista', 'city': 'Paulista', 'municipality': 'Região Geográfica Imediata do Recife', 'county': 'Região Metropolitana do Recife', 'state': 'Pernambuco', 'region': 'Região Nordeste', 'postcode': '53417-040', 'country': 'Brasil', 'country_code': 'br'}, 'boundingbox': ['-7.9350466', '-7.9349466', '-34.8987594', '-34.8986594']}
# ...

# %%
df_ends_points3.shape
# Out:
# (38, 8)

# %%
df_ends_points_sem_na2 = df_ends_points_sem_na[df_ends_points_sem_na["Endereço completíssimo"]==""]

# %%
lista_coordenadas =     df_ends_points_sem_na["Coord"].values
print(lista_coordenadas)
# Out:
# ['-7.93516, -34.89865' '-7.93326, -34.89885' '-7.93516, -34.89865' ...
#  '-7.9715, -34.86606' '-7.97144, -34.86641' '-7.98263, -34.85657']

# %%
len(lista_coordenadas)
# Out:
# 9109

# %%
lista_coordenadas_restante = lista_coordenadas[8327:]
len(lista_coordenadas_restante)
# Out:
# 782

# %%
endereços_completissimos_list_restante = []

# %%
for coorden in lista_coordenadas_restante:
    endereço = geopy.geocoders.Nominatim(user_agent="Intro Geocode").reverse(coorden)
    endereços_completissimos_list_restante.append(endereço)

# %%
endereços_completissimos_lista = endereços_completissimos_list +endereços_completissimos_list_restante
len(endereços_completissimos_lista)
# Out:
# 9109

# %%
len(endereços_completissimos_list_restante)
# Out:
# 782

# %%
endereços_completissimos_list = []

# %%
len(endereços_completissimos_list)
# Out:
# 8327

# %%
df_ends_points2 = df_ends_points.copy()

# %%
df_ends_points['Coord'] = str(df_ends_points['y']) + "," + str(df_ends_points['x'])
df_ends_points.head()
# Out:
#    Unnamed: 0                              Endereço semicompleto  \
# 0           0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1           1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
# 2           2  Av. Lindolfo Collor, 97 | Supermercado Soberan...
# 3           3  Av. Lindolfo Collor, 30 | Praça Da Liberdade, ...
# 4           4  Av. Lindolfo Collor, 38 | China Bar, Pernambuc...
#
#                                     Endereço geocode               Points  \
# 0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 1  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...  -34.89885, -7.93326
# 2  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 3  0    Praça da Liberdade - Av. Lindolfo Collor ...  -34.89871, -7.93639
# 4  0    Av. Lindolfo Collor, 86 - Paratibe, Pauli...  -34.89884, -7.93580
#
#           x        y                                              Coord
# ...

# %%
type(df_ends_points.Points[0])
# Out:
# str

# %%
str(df_ends_points.Points[0])
# Out:
# '-34.89865, -7.93516'

# %%
df_ends_points.head(2)
# Out:
#    Unnamed: 0                              Endereço semicompleto  \
# 0           0  Av. Lindolfo Collor, 03 | Miniterminal De Para...
# 1           1  Av. Lindolfo Collor, 127 | Escola Custódio Pes...
#
#                                     Endereço geocode               Points  \
# 0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...  -34.89865, -7.93516
# 1  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...  -34.89885, -7.93326
#
#           x        y
# 0 -34.89865 -7.93516
# 1 -34.89885 -7.93326

# %%
from shapely.geometry import Point

# %%
coorden = pd.DataFrame()

# %%
coorden['Points'] =(-34.89865, -7.93516)

#tuple(map(int, df_ends_points['Points'].split(', ')))

# %%
print(geopy.geocoders.GoogleV3(user_agent="Intro Geocode", api_key="AIzaSyAt2800EHvRPwF6tSIz3gim51knlQMPH8g").reverse('-7.93516, -34.89865')
     )
# Out:
# Av. Lindolfo Collor, 94 - Paratibe, Paulista - PE, 53413-150, Brazil

# %%
print(geopy.geocoders.Nominatim(user_agent="Intro Geocode").reverse('-7.93516, -34.89865') )
# Out:
# 140408, Avenida Lindolfo Collor, Paratibe, Paulista, Região Geográfica Imediata do Recife, Região Metropolitana do Recife, Pernambuco, Região Nordeste, 53417-040, Brasil

# %%
len(points)
# Out:
# 9444

# %%
datafram_export = pd.DataFrame()
datafram_export["Endereço completíssimos"] = endereços_completissimos
datafram_export["Points"] = points

# %%
datafram_export
# Out:
#                                 Endereço completíssimos  \
# 0     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 1     0    Av. Lindolfo Collor, SN - Paratibe, Pauli...
# 2     0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 3     0    Praça da Liberdade - Av. Lindolfo Collor ...
# 4     0    Av. Lindolfo Collor, 86 - Paratibe, Pauli...
# ...                                                 ...
# 9439  0    Av. Tabajara, 55 - Tabajara, Olinda - PE,...
# 9440  0    Av. Tabajara, 52 - Tabajara, Olinda - PE,...
# 9441  0    Av. Tabajara, 65 - Loja B - Tabajara, Oli...
# 9442  0    R. Orobó, 51 - Tabajara, Olinda - PE, 533...
# 9443  0    Terminal Integrado da PE-015 - Av. Pan No...
#
#                                                  Points
# 0     0    POINT (-34.89865 -7.93516)\nName: geometr...
# 1     0    POINT (-34.89885 -7.93326)\nName: geometr...
# 2     0    POINT (-34.89865 -7.93516)\nName: geometr...
# 3     0    POINT (-34.89871 -7.93639)\nName: geometr...
# ...

# %%
datafram_export.to_csv("endereços_semicompletos_e_coordenadas.csv", encoding="utf-8")

# %%
points_csv = pd.read_csv('endereços_semicompletos_e_coordenadas.csv', encoding="utf-8")

# %%
points_csv.head(9150)
# Out:
#       Unnamed: 0                            Endereço completíssimos  \
# 0            0.0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 1            1.0  0    Av. Lindolfo Collor, SN - Paratibe, Pauli...
# 2            2.0  0    Av. Lindolfo Collor, 94 - Paratibe, Pauli...
# 3            3.0  0    Praça da Liberdade - Av. Lindolfo Collor ...
# 4            4.0  0    Av. Lindolfo Collor, 86 - Paratibe, Pauli...
# ...          ...                                                ...
# 9145      9145.0  0    R. Edvaldo Maranhão Ferreira - Torrões, R...
# 9146      9146.0  0    R. Mte. Vitalino, 5 - Agamenon Magalhães,...
# 9147      9147.0  0    R. Ocidental, Recife - PE, 50721-610, Bra...
# 9148      9148.0  0    Av. Inácio Monteiro, 747 - Cordeiro, Reci...
# 9149      9149.0  0    Av. Inácio Monteiro, 539 - Cordeiro, Reci...
#
#                    Points
# 0      -34.89865 -7.93516
# 1      -34.89885 -7.93326
# 2      -34.89865 -7.93516
# 3      -34.89871 -7.93639
# ...

# %%
df_completo = pd.DataFrame()

# %%
len(endereços_distintos)
# Out:
# 9147

# %%
points_corrigidos = []
for coord in points:
    coord_temp = coord.replace("0    POINT (","")
    coord_ok = coord_temp.replace(")\nName: geometry, dtype: geometry","")
    points_corrigidos.append(coord_ok)
points_corrigidos[:5]
# Out:
# ['-34.89865 -7.93516',
#  '-34.89885 -7.93326',
#  '-34.89865 -7.93516',
#  '-34.89871 -7.93639',
#  '-34.89884 -7.93580']

# %%
lat_long_lista = []
for coord in points_corrigidos:
    lat_long = coord.split()
    lat_long_lista.append(lat_long)
lat_long_lista[:5]
#Depois adicionar ao dataframe final e mudar o tipo de dados para float
# Out:
# [['-34.89865', '-7.93516'],
#  ['-34.89885', '-7.93326'],
#  ['-34.89865', '-7.93516'],
#  ['-34.89871', '-7.93639'],
#  ['-34.89884', '-7.93580']]
